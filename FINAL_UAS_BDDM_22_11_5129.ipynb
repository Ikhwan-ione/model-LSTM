# %% [markdown]
# # **UAS BIG DATA MINING**
#
# # PREDIKSI HARGA ETHEREUM (ETH) MENGGUNAKAN LSTM
#
# Nama : Ikhwan Nurramadhan
#
# NIM : 22.11.5129
#
# Kelas : BDDM 8
#
# Link Dataset : https://www.kaggle.com/datasets/kapturovalexander/bitcoin-and-ethereum-prices-from-start-to-2023

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv('/content/drive/MyDrive/SEMESTER 5/BIG DATA MINING/ETH-USD (2017-2024).csv')
df2 = pd.read_csv('/content/drive/MyDrive/SEMESTER 5/BIG DATA MINING/ETH-USD (01-05.2024).csv')

# %%
df1.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-11-10  320.670990  324.717987  294.541992  299.252991  299.252991
# 1  2017-11-11  298.585999  319.453003  298.191986  314.681000  314.681000
# 2  2017-11-12  314.690002  319.153015  298.513000  307.907990  307.907990
# 3  2017-11-13  307.024994  328.415009  307.024994  316.716003  316.716003
# 4  2017-11-14  316.763000  340.177002  316.763000  337.631012  337.631012
#
#          Volume
# 0  8.859860e+08
# 1  8.423010e+08
# 2  1.613480e+09
# 3  1.041890e+09
# 4  1.069680e+09

# %%
df2.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2024-01-01  2282.870361  2352.327881  2267.018066  2352.327881
# 1  2024-01-02  2352.593506  2431.212402  2348.892334  2355.836426
# 2  2024-01-03  2355.981445  2385.117676  2113.925293  2210.761963
# 3  2024-01-04  2210.529053  2294.608154  2204.865723  2269.038086
# 4  2024-01-05  2269.409424  2276.764648  2209.537109  2268.647217
#
#      Adj Close        Volume
# 0  2352.327881  6.906766e+09
# 1  2355.836426  1.291054e+10
# 2  2210.761963  1.933293e+10
# 3  2269.038086  1.104456e+10
# 4  2268.647217  1.086095e+10

# %% [markdown]
# # EDA & Preprocessing Data

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2264 entries, 0 to 2263
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2264 non-null   object
#  1   Open       2263 non-null   float64
#  2   High       2263 non-null   float64
#  3   Low        2263 non-null   float64
#  4   Close      2263 non-null   float64
#  5   Adj Close  2263 non-null   float64
#  6   Volume     2263 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 123.9+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       122 non-null    object
#  1   Open       121 non-null    float64
#  2   High       121 non-null    float64
#  3   Low        121 non-null    float64
#  4   Close      121 non-null    float64
#  5   Adj Close  121 non-null    float64
#  6   Volume     121 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 6.8+ KB

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
df = pd.concat([df1, df2], axis=0)

# %%
df.sort_values(by='Date', inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df = df.set_index('Date')

# %%
#Menambah Fitur
df['MA5'] = df['Close'].rolling(window=5).mean()
df['Volume_MA5'] = df['Volume'].rolling(window=5).mean()
df['Price_Change'] = df['Close'] - df['Open']

# %%
df.isna().sum()
# Out:
# Open             2
# High             2
# Low              2
# Close            2
# Adj Close        2
# Volume           2
# MA5             11
# Volume_MA5      11
# Price_Change     2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop(columns=['Adj Close'], inplace=True)

# %%
df.drop_duplicates()
# Out:
#                    Open         High          Low        Close        Volume  \
# Date
# 2017-11-14   316.763000   340.177002   316.763000   337.631012  1.069680e+09
# 2017-11-15   337.963989   340.911987   329.812988   333.356995  7.226660e+08
# 2017-11-16   333.442993   336.158997   323.605988   330.924011  7.972540e+08
# 2017-11-17   330.166992   334.963989   327.523010   332.394012  6.217330e+08
# 2017-11-18   331.980011   349.615997   327.687012   347.612000  6.496390e+08
# ...                 ...          ...          ...          ...           ...
# 2024-04-25  3139.624268  3190.976318  3074.804688  3156.509521  1.398903e+10
# 2017-11-22  360.312012  381.420013  360.147003  380.652008  8.008190e+08
# 2017-11-23  381.438995  425.548004  376.088013  410.165985  1.845680e+09
#
#                    MA5    Volume_MA5  Price_Change
# Date
# 2017-11-14  315.237799  1.090667e+09     20.868012
# 2017-11-15  322.058600  1.058003e+09     -4.606994
# 2017-11-16  325.307202  1.048994e+09     -2.518982
# 2017-11-17  330.204407  8.506446e+08      2.227020
# 2017-11-18  336.383606  7.721944e+08     15.631989
# 2017-11-19  339.734601  7.945644e+08      6.984985
# 2017-11-20  346.409204  8.114366e+08     12.636017
# 2017-11-21  352.304602  8.419682e+08     -7.041992
# 2017-11-22  361.956201  8.777854e+08     20.339996
# 2017-11-23  374.466998  1.116994e+09     28.726990

# %% [markdown]
# # Normalisasi Data

# %%
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df)

# %%
df_scaled = pd.DataFrame(df_scaled, columns=df.columns, index=df.index)

# %%
print(df_scaled.head())
# Out:
#                 Open      High       Low     Close    Volume       MA5  \
# Date
# 2017-11-14  0.049195  0.053020  0.050469  0.053582  0.005342  0.049463
# 2017-11-15  0.053681  0.053173  0.053284  0.052678  0.001204  0.050936
# 2017-11-16  0.052724  0.052184  0.051945  0.052163  0.002093  0.051638
# 2017-11-17  0.052031  0.051936  0.052790  0.052474  0.000000  0.052695
# 2017-11-18  0.052415  0.054984  0.052825  0.055693  0.000333  0.054030
#
#             Volume_MA5  Price_Change
# Date
# 2017-11-14    0.005145      0.643303
# 2017-11-15    0.004617      0.625921
# 2017-11-16    0.004472      0.627346
# 2017-11-17    0.001267      0.630584
# 2017-11-18    0.000000      0.639730

# %%
df_scaled = df_scaled.to_numpy()

# %%
sequence_length = 14
X, y = [], []
for i in range(sequence_length, len(df_scaled)):
    X.append(df_scaled[i-sequence_length:i])
    y.append(df_scaled[i, 3])  # Predicting 'Close' price
X, y = np.array(X), np.array(y)

# %% [markdown]
# # Split Data

# %%
train_size = int(0.7 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
print('X_train.shape = ',X_train.shape)
print('y_train.shape = ', y_train.shape)
print('X_test.shape = ', X_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# X_train.shape =  (1652, 14, 8)
# y_train.shape =  (1652,)
# X_test.shape =  (709, 14, 8)
# y_test.shape =  (709,)

# %%
plt.figure(figsize=(10, 5))
plt.bar(['Training Data', 'Testing Data'], [len(X_train), len(X_test)], color=['skyblue', 'lightcoral'])
plt.title('Data Split: Training vs. Testing')
plt.ylabel('Number of Samples')
plt.show()

# %% [markdown]
# # Model LSTM

# %%
model = Sequential([
        LSTM(60,activation='tanh' ,return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
        Dropout(0.15),
        LSTM(50,activation='tanh' ,return_sequences=True),
        Dropout(0.15),
        LSTM(40,activation='tanh' ,return_sequences=False),
        Dropout(0.15),
        Dense(1)
    ])
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 14, 60)              │          16,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 14, 60)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 14, 50)              │          22,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 14, 50)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 40)                  │          14,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 40)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              41 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 53,361 (208.44 KB)
#  Trainable params: 53,361 (208.44 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=16)
# Out:
# Epoch 1/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - loss: 0.0140 - val_loss: 0.0014
# Epoch 2/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0032 - val_loss: 0.0013
# Epoch 3/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 4/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 5/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0029 - val_loss: 9.9755e-04
# Epoch 6/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0028 - val_loss: 9.2801e-04
# Epoch 7/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 8/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 9/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 10/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - loss: 0.0024 - val_loss: 6.8585e-04
# Epoch 11/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.0018 - val_loss: 7.7641e-04
# Epoch 12/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 13/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 0.0022 - val_loss: 6.7485e-04
# Epoch 14/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 15/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 16/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0016 - val_loss: 6.3854e-04
# Epoch 17/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0014 - val_loss: 7.7182e-04
# Epoch 18/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0015 - val_loss: 7.3657e-04
# Epoch 19/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 20/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 21/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - loss: 0.0014 - val_loss: 4.2904e-04
# Epoch 22/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.0013 - val_loss: 4.9737e-04
# Epoch 23/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 0.0013 - val_loss: 3.7572e-04
# Epoch 24/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 0.0014 - val_loss: 8.3323e-04
# Epoch 25/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0013 - val_loss: 7.9722e-04
# Epoch 26/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 27/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0014 - val_loss: 8.7174e-04
# Epoch 28/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 0.0013 - val_loss: 4.5981e-04
# Epoch 29/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0012 - val_loss: 3.2956e-04
# Epoch 30/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0014 - val_loss: 5.5124e-04
# Epoch 31/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0013 - val_loss: 2.8633e-04
# Epoch 32/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0010 - val_loss: 3.7893e-04
# Epoch 33/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0016 - val_loss: 4.6507e-04
# Epoch 34/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0013 - val_loss: 5.1626e-04
# Epoch 35/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 9.5305e-04 - val_loss: 4.9431e-04
# Epoch 36/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 37/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0011 - val_loss: 6.2705e-04
# Epoch 38/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - loss: 9.9835e-04 - val_loss: 5.5538e-04
# Epoch 39/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 9.9279e-04 - val_loss: 2.8343e-04
# Epoch 40/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0010 - val_loss: 3.0664e-04
# Epoch 41/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 9.1860e-04 - val_loss: 0.0012
# Epoch 42/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - loss: 9.5039e-04 - val_loss: 3.7698e-04
# Epoch 43/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 9.9498e-04 - val_loss: 2.4973e-04
# Epoch 44/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 9.0348e-04 - val_loss: 2.4079e-04
# Epoch 45/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.8994e-04 - val_loss: 2.3607e-04
# Epoch 46/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 9.3939e-04 - val_loss: 2.4627e-04
# Epoch 47/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - loss: 8.8751e-04 - val_loss: 2.7448e-04
# Epoch 48/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.8852e-04 - val_loss: 2.5483e-04
# Epoch 49/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 9.3921e-04 - val_loss: 9.6135e-04
# Epoch 50/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 9.8734e-04 - val_loss: 3.2492e-04

# %%
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Model Loss During Training')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Hasil Model

# %%
y_pred = model.predict(X_test)
y_test_rescaled = scaler.inverse_transform(np.concatenate((np.zeros((len(y_test), 7)), y_test.reshape(-1, 1)), axis=1))[:, -1]
y_pred_rescaled = scaler.inverse_transform(np.concatenate((np.zeros((len(y_pred), 7)), y_pred), axis=1))[:, -1]
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step

# %%
# Visualizing predictions vs actual
plt.figure(figsize=(12, 6))
plt.plot(y_test_rescaled, label='Actual Prices', color='blue')
plt.plot(y_pred_rescaled, label='Predicted Prices', color='red', linestyle='dashed')
plt.title('Actual vs Predicted Close Prices')
plt.xlabel('Time Steps')
plt.ylabel('Close Price')
plt.legend()
plt.grid()
plt.show()

# %%
# Melihat 100 data terakhir dari prediksi
plt.figure(figsize=(12, 6))
plt.plot(y_test_rescaled[-100:], label='Actual Prices', color='blue')
plt.plot(y_pred_rescaled[-100:], label='Predicted Prices', color='red', linestyle='dashed')
plt.title('Actual vs Predicted Close Prices (Last 100 Steps)')
plt.xlabel('Time Steps')
plt.ylabel('Close Price')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Evaluasi Model

# %%
errors = y_test_rescaled - y_pred_rescaled
plt.figure(figsize=(10, 5))
plt.hist(errors, bins=20, color='purple', edgecolor='black')
plt.title('Distribution of Prediction Errors')
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %%
# Metrics
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-squared (R2) Score: {r2:.4f}")
# Out:
# Mean Squared Error (MSE): 697.9493
# Root Mean Squared Error (RMSE): 26.4187
# Mean Absolute Error (MAE): 19.8807
# R-squared (R2) Score: 0.9809
